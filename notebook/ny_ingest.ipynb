# %% [markdown]
# # Ingestion for NY Data

# %%
# Import system packages.
import sys, os
import urllib.parse
import datetime
import json

# Import data processing tools
import pandas as pd

# Import MongoDB related packages.
from pymongo import MongoClient
from dotenv import dotenv_values
from bson.objectid import ObjectId

# %%
# Load the environment variables.
ENV_PATH = "./../.env"
config = { 
    **dotenv_values(ENV_PATH + ".config"),
    **dotenv_values(ENV_PATH + ".secrets"),
    **os.environ,
}

config['LOOKUP_SHEETS'] = config['LOOKUP_SHEETS'].split(',')

# %%
# Import Database class.
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\connection")
from database import Database

# %%
# Initialize and connect to the MongoDB client and show client details.
Database.initialize(config)
# Out:
# OK
# MongoClient(host=['mongodb.thelionsredmane.stream:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin')

# %%
# Use specific database and show details.
Database.use("providers")
# Out:
# OK
# Database(MongoClient(host=['mongodb.thelionsredmane.stream:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin'), 'providers')

# %% [markdown]
# ## NYS Provider Ingestion
#
# The `providers` database has the following collections:
# - `ny_providers# Preview pandas.DataFrame information.
# def preview(df):
#     if df is not None:
#         print(df.head())
#         print(df.tail())
#         print(df.info())`

# %%
# Preview pandas.DataFrame information.
def preview(df):
    if df is not None:
        print(df.head())
        print(df.tail())
        print(df.info())

# %%
# Load in dataset for the lookup table.
def load_sheet(filename, sheet, **settings):
    df = None
    with open(filename, "rb") as excel:
        df = pd.read_excel(excel, sheet_name=sheet, **settings)
    return df

# %%
# Prepare the providers URI.
uri = config['NY_PROVIDERS'].split('#')
filename = "./../data/" + uri[0]
worksheets = uri[1].split(',')
print(filename)
print(worksheets)
# Out:
# ./../data/gov.nys.serviceproviders.xlsx
# ['ddso_service_providers', 'ddso_discharge_facilities', 'ofa_service_providers', 'cil_service_providers']

# %% [markdown]
# ## Service Providers
#
# Generally service providers have the following important fields:
#
# ```yaml
# facility: <str>
# info:
#   phone: [<XXX-XXX-XXXX>]
#   fax: [<XXX-XXX-XXXX>]
#   website: <subdomain.domain.com>
#   person: <entity>
# keywords: [<str>,...]
# address:
#   street:
#     line_1: <str>
#     line_2: <str>
#   city: <city>
#   county: <county>
#   state: <state>
#   zipcode: <zipcode>
# category:
#   disability: [<str>,...]
#   service: [<str>,...]
# misc:
#   content: [<str>,...]
#   <key>: <value>
# ```

# %%
# Method for preparing a service provider.
class Provider:    
    """Provider instance."""
    def __init__(self, data, **kwargs):
        self.data = { **data }
        self.data['misc'] = {
            **self.data.get('misc', {}),
            **kwargs
        }
        
    def to_dict(self):
        return { **self.data }

# %%
def to_records(df, columns=None):
    # Set df_view
    df_view = df
    
    if columns:
        df_view.columns = columns
        
    return df_view.to_dict("records")

# %%
# Prepare the NY Providers table.
ddso_df = load_sheet(filename, worksheets[0], index_col=None, usecols=list(range(0, 22)))
ddso_df
# Out:
#     Developmental Disability Services Office  \
# 0                        METRO NEW YORK DDSO
# 1                                BROOME DDSO
# 2                         HUDSON VALLEY DDSO
# 3                        METRO NEW YORK DDSO
# 4                           LONG ISLAND DDSO
# ..                                       ...
# 528                            BROOKLYN DDSO
# 529                         LONG ISLAND DDSO
# 530                        FINGER LAKES DDSO
# 531                    CENTRAL NEW YORK DDSO
# 532                         LONG ISLAND DDSO
#
#                   Service Provider Agency                  Street Address  \
# 0                        UNIQUE LIFE INC.        2197 NEW ENGLAND THRUWAY
# 1              BROOME COUNTY URBAN LEAGUE            43-45 CARROLL STREET
# 2                           OPENGATE INC.                 357 MAIN STREET
# 3         COMMUNITY OPTIONS NEW YORK INC.                  350 5TH AVENUE
# 4               CENTER FOR RAPID RECOVERY            312 GREENWICH STREET
# ..                                    ...                             ...
# 528   UNIQUE CARE COMMUNITY SERVICES INC.                   9317 AVENUE L
# 529               SUFFOLK CO. NYSARC INC.  2900 VETERANS MEMORIAL HIGHWAY
# 530               ONTARIO CO. NYSARC INC.       3071 COUNTY COMPLEX DRIVE
# 531                    HERITAGE FARM INC.             3599 STATE ROUTE 46
# 532  CENTER FOR FAMILY SUPPORT INC. (THE)            110 JERICHO TURNPIKE
#
#     Street Address Line 2         City State  Zip Code         Phone  \
# 0                     NaN        BRONX    NY     10475  347-449-7890
# 1                     NaN   BINGHAMTON    NY     13901  607-723-7303
# 2                     NaN       ARMONK    NY     10504  914-277-5350
# 3              SUITE 5230     NEW YORK    NY     10118  212-227-9110
# 4                     NaN    HEMPSTEAD    NY     11550  516-292-6449
# ..                    ...          ...   ...       ...           ...
# 528                   NaN     BROOKLYN    NY     11236  347-502-2956
# 529                   NaN      BOHEMIA    NY     11716  631-585-0100
# 530                   NaN  CANANDAIGUA    NY     14424  585-394-7500
# 531   R.D.#1 P.O. BOX 143   BOUCKVILLE    NY     13310  315-893-1889
# 532             SUITE 103  FLORAL PARK    NY     11001  516-292-3000
#
#           County                   Website Url  ... Family Care  \
# 0          BRONX  http://www.uniquelifeinc.org  ...           N
# 1         BROOME           http://www.bcul.org  ...           N
# 2    WESTCHESTER    http://www.opengateinc.org  ...           N
# 3       NEW YORK          http://www.comop.org  ...           N
# 4         NASSAU  http://www.rapidrecovery.org  ...           N
# ..           ...                           ...  ...         ...
# 528        KINGS                           NaN  ...           N
# 529      SUFFOLK    http://www.ahrcsuffolk.org  ...           N
# 530      ONTARIO     http://www.ontarioarc.org  ...           Y
# 531      MADISON    http://heritagefarminc.org  ...           N
# 532       NASSAU          http://www.cfsny.org  ...           N
#
#     Self-Direction Services Individual Support Services (ISSs)  \
# 0                         Y                                  Y
# 1                         N                                  N
# 2                         N                                  N
# 3                         N                                  Y
# 4                         N                                  N
# ..                      ...                                ...
# 528                       N                                  N
# 529                       N                                  N
# 530                       N                                  N
# 531                       N                                  N
# 532                       N                                  Y
#
#     Day Habilitation Prevocational Supported Employment Enrollments  \
# 0                  Y             N                                N
# 1                  N             N                                N
# 2                  Y             N                                Y
# 3                  Y             Y                                Y
# 4                  Y             N                                N
# ..               ...           ...                              ...
# 528                Y             N                                N
# 529                Y             Y                                Y
# 530                Y             Y                                Y
# 531                Y             N                                Y
# 532                N             N                                N
#
#     Community Habilitation Family Support Services  \
# 0                        Y                       Y
# 1                        N                       Y
# 2                        Y                       Y
# 3                        Y                       N
# 4                        Y                       Y
# ..                     ...                     ...
# 528                      Y                       Y
# 529                      Y                       Y
# 530                      Y                       Y
# 531                      Y                       Y
# 532                      Y                       Y
#
#     Developmental Centers And Special Population Services  \
# 0                                                    N
# 1                                                    N
# 2                                                    N
# 3                                                    N
# 4                                                    N
# ..                                                 ...
# 528                                                  N
# 529                                                  N
# 530                                                  N
# 531                                                  N
# 532                                                  N
#
#                                             Location 1
# 0                                                  NaN
# 1    43-45 CARROLL STREET\n BINGHAMTON, NY 13901\n ...
# 2    357 MAIN STREET\n ARMONK, NY 10504\n (41.12418...
# 3    350 5TH AVENUE\n NEW YORK, NY 10118\n (40.7480...
# 4    312 GREENWICH STREET\n HEMPSTEAD, NY 11550\n (...
# ..                                                 ...
# 528  9317 AVENUE L\n BROOKLYN, NY 11236\n (40.63681...
# 529  2900 VETERANS MEMORIAL HIGHWAY\n BOHEMIA, NY 1...
# 530  3071 COUNTY COMPLEX DRIVE\n CANANDAIGUA, NY 14...
# 531  3599 STATE ROUTE 46\n BOUCKVILLE, NY 13310\n (...
# 532  110 JERICHO TURNPIKE\n FLORAL PARK, NY 11001\n...
#
# [533 rows x 22 columns]

# %%
ddso_df.head()
# Out:
#   Developmental Disability Services Office          Service Provider Agency  \
# 0                      METRO NEW YORK DDSO                 UNIQUE LIFE INC.
# 1                              BROOME DDSO       BROOME COUNTY URBAN LEAGUE
# 2                       HUDSON VALLEY DDSO                    OPENGATE INC.
# 3                      METRO NEW YORK DDSO  COMMUNITY OPTIONS NEW YORK INC.
# 4                         LONG ISLAND DDSO        CENTER FOR RAPID RECOVERY
#
#              Street Address Street Address Line 2        City State  Zip Code  \
# 0  2197 NEW ENGLAND THRUWAY                   NaN       BRONX    NY     10475
# 1      43-45 CARROLL STREET                   NaN  BINGHAMTON    NY     13901
# 2           357 MAIN STREET                   NaN      ARMONK    NY     10504
# 3            350 5TH AVENUE            SUITE 5230    NEW YORK    NY     10118
# 4      312 GREENWICH STREET                   NaN   HEMPSTEAD    NY     11550
#
#           Phone       County                   Website Url  ... Family Care  \
# 0  347-449-7890        BRONX  http://www.uniquelifeinc.org  ...           N
# 1  607-723-7303       BROOME           http://www.bcul.org  ...           N
# 2  914-277-5350  WESTCHESTER    http://www.opengateinc.org  ...           N
# 3  212-227-9110     NEW YORK          http://www.comop.org  ...           N
# 4  516-292-6449       NASSAU  http://www.rapidrecovery.org  ...           N
#
#   Self-Direction Services Individual Support Services (ISSs) Day Habilitation  \
# 0                       Y                                  Y                Y
# 1                       N                                  N                N
# 2                       N                                  N                Y
# 3                       N                                  Y                Y
# 4                       N                                  N                Y
#
#   Prevocational Supported Employment Enrollments Community Habilitation  \
# 0             N                                N                      Y
# 1             N                                N                      N
# 2             N                                Y                      Y
# 3             Y                                Y                      Y
# 4             N                                N                      Y
#
#   Family Support Services  \
# 0                       Y
# 1                       Y
# 2                       Y
# 3                       N
# 4                       Y
#
#   Developmental Centers And Special Population Services  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#                                           Location 1
# 0                                                NaN
# 1  43-45 CARROLL STREET\n BINGHAMTON, NY 13901\n ...
# 2  357 MAIN STREET\n ARMONK, NY 10504\n (41.12418...
# 3  350 5TH AVENUE\n NEW YORK, NY 10118\n (40.7480...
# 4  312 GREENWICH STREET\n HEMPSTEAD, NY 11550\n (...
#
# [5 rows x 22 columns]

# %%
def get_ddso_facility(df):    
    return df.iloc[:,[0,1]].agg(' - '.join, axis=1)
facilities = get_ddso_facility(ddso_df)

# %%
def get_ddso_info(df):
    phone = df.loc[:, df.columns.isin(['Phone'])]
    website = df.loc[:, df.columns.isin(['Website Url'])]
    return {
        'phone': phone,
        'website': website,
    }
infos = get_ddso_info(ddso_df)

# %%
def get_ddso_address(df):
    street = {
        'line1': df.loc[:, df.columns.isin(['Street Address Line 1'])],
        'line2': df.loc[:, df.columns.isin(['Street Address Line 2'])],
        'line3': df.loc[:, df.columns.isin(['Location 1'])],
    }
    city = df.loc[:, df.columns.isin(['City'])]
    county = df.loc[:, df.columns.isin(['County'])]    
    state = df.loc[:, df.columns.isin(['State'])]
    zipcode = df.loc[:, df.columns.isin(['Zip Code'])]
    return {
        'street': street,
        'city': city,
        'county': county,
        'state': state,
        'zipcode': zipcode
    }
addresses = get_ddso_address(ddso_df)

# %% [markdown]
# ## Categories
#
# `disability_category`:
# - Ambulatory
# - Hearing
# - Cognitive
# - Vision
# - Independent Living
# - Self-care
# - Other
#
# `service_category`:
# - Communication Services
# - Advocacy Services
# - Job Development and Placement
# - Information and Retrieval
# - Counseling
# - Independent Living Skill Instruction
# - Community Education

# %%
def get_ddso_keywords(df):
    
    ICF = df['Intermediate Care Facilities (ICFs)'].map({'Y': "Intermediate Care Facilities ICF", 'N': None})
    IRA = df['Individual Residential Alternative (IRA)'].map({'Y': "Individual Residential Alternative IRA", 'N': None})
    FC = df['Family Care'].map({'Y': "Family Care", 'N': None})
    SDS = df['Self-Direction Services'].map({'Y': "Self Direction Services", 'N': None})
    ISS = df['Individual Support Services (ISSs)'].map({'Y': "Individual Support Services ISS", 'N': None})
    DH = df['Day Habilitation'].map({'Y': "Day Habilitation", 'N': None})
    PV = df['Prevocational'].map({'Y': "Prevocational", 'N': None})
    SEE = df['Supported Employment Enrollments'].map({'Y': "Supported Employment Enrollments", 'N': None})
    CH = df['Community Habilitation'].map({'Y': "Community Habilitation", 'N': None})
    FSS = df['Family Support Services'].map({'Y': "Family Support Services", 'N': None})
    DCSPS = df['Developmental Centers And Special Population Services'].map({'Y': "Developmental Centers and Special Population Services", 'N': None})
    keyword_df = [ICF, IRA, FC, SDS, ISS, DH, PV, SEE, CH, FSS, DCSPS]
    keyword_df = pd.concat(keyword_df, axis=1) 
    
    keyword_df.columns = ['ICF', 'IRA','FC', 'SDS', 'ISS', 'DH', 'PV', 'SEE', 'CH', 'FSS', 'DCSPS']
    return keyword_df.fillna('').astype(str).apply(lambda x: ' '.join(x.str.lower().str.strip()), axis=1)
keywords = get_ddso_keywords(ddso_df)

# %%
categories = [
    ['ambulatory', 'hearing', 'deaf', 'hoh', 'hard of hearing', 'cognitive', 'vision', 'independent living', 'self-care', 'other'],
    ['communication', 'advocacy', 'job', 'development', 'placement', 'information', 'retireval', 'counseling', 'independent', 'living', 'skill', 'instruction', 'community','education']
]

# %%
def get_at(df, i):
    return df.iloc[i]

# [{ 'a': i } for i in range(ddso_df.shape[0])]

payload = [{ 
    'facility': get_at(facilities, i),
    'info': {
        'phone': infos.get('phone').iloc[i].astype(str)[0],
        'website': infos.get('website').iloc[i].astype(str)[0],
    },
    'address': {
        # 'street': {
             # 'line1': addresses.get('street').get('line1').iloc[i].astype(str)[0],
             # 'line2': addresses.get('street').get('line2').iloc[i].astype(str)[0],
             # 'line3': addresses.get('street').get('line3').iloc[i].astype(str)[0],
        # },
        'city': addresses.get('city').iloc[i][0],
        'county': addresses.get('county').iloc[i][0],
        'state': addresses.get('state').iloc[i][0],
        'zipcode': int(addresses.get('zipcode').iloc[i][0])
    },
    'keywords': ",".join(get_at(keywords, i).split()),
    # 'category': {},
    # 'misc': {}
 } for i in range(ddso_df.shape[0])]

payload
# Out:
# [{'facility': 'METRO NEW YORK DDSO - UNIQUE LIFE INC.',
#   'info': {'phone': '347-449-7890', 'website': 'http://www.uniquelifeinc.org'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10475},
#   'keywords': 'self,direction,services,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'BROOME DDSO - BROOME COUNTY URBAN LEAGUE',
#   'info': {'phone': '607-723-7303', 'website': 'http://www.bcul.org'},
#   'address': {'city': 'BINGHAMTON',
#    'county': 'BROOME',
#    'state': 'NY',
#    'zipcode': 13901},
#   'keywords': 'family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - OPENGATE INC.',
#   'info': {'phone': '914-277-5350', 'website': 'http://www.opengateinc.org'},
#   'address': {'city': 'ARMONK',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10504},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - COMMUNITY OPTIONS NEW YORK INC.',
#   'info': {'phone': '212-227-9110', 'website': 'http://www.comop.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10118},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation'},
#  {'facility': 'LONG ISLAND DDSO - CENTER FOR RAPID RECOVERY',
#   'info': {'phone': '516-292-6449', 'website': 'http://www.rapidrecovery.org'},
#   'address': {'city': 'HEMPSTEAD',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11550},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - TOWN OF BABYLON RECREATION PROGRAM',
#   'info': {'phone': '631-422-7642', 'website': 'nan'},
#   'address': {'city': 'LINDENHURST',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11757},
#   'keywords': 'family,support,services'},
#  {'facility': 'CAPITAL DISTRICT DDSO - NORTHEAST CAREER PLANNING (DBA)',
#   'info': {'phone': '518-465-5201',
#    'website': 'http://www.northeastcareer.org'},
#   'address': {'city': 'MENANDS',
#    'county': 'ALBANY',
#    'state': 'NY',
#    'zipcode': 12204},
#   'keywords': 'prevocational,supported,employment,enrollments'},
#  {'facility': 'STATEN ISLAND DDSO - N Y S INSTITUTE ON DISABILITY INC.',
#   'info': {'phone': '212-487-5316', 'website': 'nan'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10314},
#   'keywords': 'individual,support,services,iss,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - INDEPENDENT GROUP HOME LIVING PRGRM INC',
#   'info': {'phone': '631-878-8900', 'website': 'http://www.ighl.org'},
#   'address': {'city': 'MANORVILLE',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11949},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - WESTCHESTER JEWISH COMMUNITY SERVICES',
#   'info': {'phone': '914-949-7699', 'website': 'http://www.wjcs.com'},
#   'address': {'city': 'HARTSDALE',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10530},
#   'keywords': 'family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - THE ARC OF CHEMUNG-SCHUYLER',
#   'info': {'phone': '607-535-6934', 'website': 'http://www.arcofschuyler.org'},
#   'address': {'city': 'ELMIRA',
#    'county': 'CHEMUNG',
#    'state': 'NY',
#    'zipcode': 14901},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - HERO INC.',
#   'info': {'phone': '914-725-2481', 'website': 'http://www.hero-ny.org'},
#   'address': {'city': 'PURCHASE',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10577},
#   'keywords': 'family,support,services'},
#  {'facility': 'SUNMOUNT DDSO - 0225 - SUNMOUNT DDSO',
#   'info': {'phone': '518-359-3311', 'website': 'nan'},
#   'address': {'city': 'TUPPER LAKE',
#    'county': 'FRANKLIN',
#    'state': 'NY',
#    'zipcode': 12986},
#   'keywords': 'individual,residential,alternative,ira,family,care,day,habilitation,community,habilitation,family,support,services,developmental,centers,and,special,population,services'},
#  {'facility': 'CAPITAL DISTRICT DDSO - CATHOLIC CHARITIES OF THE DIOCESE OF ALB',
#   'info': {'phone': '518-783-1111', 'website': 'http://www.ccdservices.org'},
#   'address': {'city': 'ALBANY',
#    'county': 'ALBANY',
#    'state': 'NY',
#    'zipcode': 12205},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - TOWN OF CHEEKTOWAGA YOUTH BOARD',
#   'info': {'phone': '716-897-7207', 'website': 'http://www.tocny.org'},
#   'address': {'city': 'CHEEKTOWAGA',
#    'county': 'ERIE',
#    'state': 'NY',
#    'zipcode': 14211},
#   'keywords': 'family,support,services'},
#  {'facility': 'BERNARD M. FINESON DDSO - NYC BD OF ED PS-177Q',
#   'info': {'phone': 'nan',
#    'website': 'http://schools.nyc.gov/schoolportals/26/q177/default.htm'},
#   'address': {'city': 'FLUSHING',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11365},
#   'keywords': 'family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - RISING GROUND INC.',
#   'info': {'phone': '914-375-8700', 'website': 'http://www.leakeandwatts.org'},
#   'address': {'city': 'YONKERS',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10705},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation'},
#  {'facility': 'LONG ISLAND DDSO - EASTERN SUFFOLK BOCES',
#   'info': {'phone': '631-687-3056', 'website': 'http://www.esboces.org'},
#   'address': {'city': 'PATCHOQUE',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11772},
#   'keywords': 'supported,employment,enrollments'},
#  {'facility': 'TACONIC DDSO - WRAPAROUND SERVICES HUDSON VALLEY INC.',
#   'info': {'phone': '845-336-7235', 'website': 'http://www.cpulster.org'},
#   'address': {'city': 'LAKE KATRINE',
#    'county': 'ULSTER',
#    'state': 'NY',
#    'zipcode': 12449},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - CHEMUNG CO. NYSARC INC.',
#   'info': {'phone': '607-734-6151', 'website': 'http://www.chemungarc.org'},
#   'address': {'city': 'ELMIRA',
#    'county': 'CHEMUNG',
#    'state': 'NY',
#    'zipcode': 14901},
#   'keywords': 'community,habilitation'},
#  {'facility': 'BROOKLYN DDSO - HARMONY SERVICES INC.',
#   'info': {'phone': '718-986-7648', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11218},
#   'keywords': 'day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - KINGSBRIDGE HEIGHTS COMMUNITY CENTER',
#   'info': {'phone': '718-884-0700', 'website': 'http://www.khcc-nyc.org'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10463},
#   'keywords': 'family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - MARYHAVEN CENTER OF HOPE INC.',
#   'info': {'phone': '631-474-4120', 'website': 'http://maryhaven.chsli.org'},
#   'address': {'city': 'PT JEFFERSON STATION',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11776},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'CAPITAL DISTRICT DDSO - 0260 - CAPITAL DISTRICT DDSO',
#   'info': {'phone': '518-370-7370', 'website': 'nan'},
#   'address': {'city': 'SCHENECTADY',
#    'county': 'SCHENECTADY',
#    'state': 'NY',
#    'zipcode': 12304},
#   'keywords': 'individual,residential,alternative,ira,family,care,individual,support,services,iss,day,habilitation,supported,employment,enrollments,family,support,services'},
#  {'facility': 'SUNMOUNT DDSO - ST.LAWRENCE COUNTY ARTS COUNCIL',
#   'info': {'phone': '315-265-6860', 'website': 'http://www.slartscouncil.org'},
#   'address': {'city': 'POTSDAM',
#    'county': 'ST. LAWRENCE',
#    'state': 'NY',
#    'zipcode': 13676},
#   'keywords': 'family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - CHILDREN OF PROMISE STABLE INC.',
#   'info': {'phone': '845-304-9657', 'website': 'http://www.copsbarn.org'},
#   'address': {'city': 'NANUET',
#    'county': 'ROCKLAND',
#    'state': 'NY',
#    'zipcode': 10954},
#   'keywords': 'family,support,services'},
#  {'facility': 'TACONIC DDSO - IN FLIGHT INC.',
#   'info': {'phone': '845-835-6060', 'website': 'nan'},
#   'address': {'city': 'RED HOOK',
#    'county': 'DUTCHESS',
#    'state': 'NY',
#    'zipcode': 12571},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - PARTNERSHIP FOR INNOVATIVE COMPREHENSIVE',
#   'info': {'phone': '212-480-9169', 'website': 'nan'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10001},
#   'keywords': 'individual,support,services,iss,community,habilitation'},
#  {'facility': 'WESTERN NEW YORK DDSO - SOUTHWESTERN INDEPENDENT LIVING CTR',
#   'info': {'phone': '716-661-3010',
#    'website': 'http://www.ilc-jamestown-ny.org'},
#   'address': {'city': 'JAMESTOWN',
#    'county': 'CHAUTAUQUA',
#    'state': 'NY',
#    'zipcode': 14701},
#   'keywords': 'family,support,services'},
#  {'facility': "LONG ISLAND DDSO - VARIETY PRE-SCHOOLER'S WORKSHOP",
#   'info': {'phone': '516-921-7171', 'website': 'http://www.vclc.org'},
#   'address': {'city': 'SYOSSET',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11791},
#   'keywords': 'family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - JOB PATH INC.',
#   'info': {'phone': '212-944-0564', 'website': 'http://www.jobpathnyc.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10018},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'STATEN ISLAND DDSO - GRACE FOUNDATION',
#   'info': {'phone': '718-983-3800', 'website': 'http://www.graceofny.org'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10314},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - 0265 - METRO NY DDSO',
#   'info': {'phone': '212-229-3000', 'website': 'nan'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10004},
#   'keywords': 'individual,residential,alternative,ira,family,care,day,habilitation'},
#  {'facility': 'FINGER LAKES DDSO - PEOPLE INC. FINGER LAKES',
#   'info': {'phone': '716-817-7400', 'website': 'http://www.people-inc.org'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14611},
#   'keywords': 'individual,residential,alternative,ira'},
#  {'facility': 'WESTERN NEW YORK DDSO - PEOPLE INC.',
#   'info': {'phone': '716-634-8132', 'website': 'http://www.people-inc.org'},
#   'address': {'city': 'WILLIAMSVILLE',
#    'county': 'ERIE',
#    'state': 'NY',
#    'zipcode': 14221},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,family,care,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - BARRY&FLORENCE FRIEDBERG JWSH CMMTY CTR',
#   'info': {'phone': '516-766-4341', 'website': 'http://www.friedbergjcc.org'},
#   'address': {'city': 'OCEANSIDE',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11803},
#   'keywords': 'family,support,services'},
#  {'facility': 'STATEN ISLAND DDSO - COMMUNITY RESOURCES FOR THE DD (DBA)',
#   'info': {'phone': '718-447-5200', 'website': 'nan'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10314},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'SUNMOUNT DDSO - UNITED HLPRS BEHVRL HEALTH & LIFE SKILLS',
#   'info': {'phone': '315-393-3072', 'website': 'http://www.unitedhelpers.org'},
#   'address': {'city': 'OGDENSBURG',
#    'county': 'ST. LAWRENCE',
#    'state': 'NY',
#    'zipcode': 13669},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,family,support,services'},
#  {'facility': 'TACONIC DDSO - THE FRIENDS NETWORK INC.',
#   'info': {'phone': '845-278-0820',
#    'website': 'http://www.thefriendsnetwork.org'},
#   'address': {'city': 'BREWSTER',
#    'county': 'PUTNAM',
#    'state': 'NY',
#    'zipcode': 10509},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'TACONIC DDSO - NEW HORIZONS RESOURCES INC.',
#   'info': {'phone': '845-473-3000', 'website': 'http://www.nhrny.org'},
#   'address': {'city': 'PLEASANT VALLEY',
#    'county': 'DUTCHESS',
#    'state': 'NY',
#    'zipcode': 12569},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - DAYBREAK INDEPENDENT SERVICES INC.',
#   'info': {'phone': '718-847-9766', 'website': 'http://www.daybreakis.org'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10470},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,prevocational,community,habilitation'},
#  {'facility': 'BERNARD M. FINESON DDSO - EIHAB HUMAN SERVICES INC.',
#   'info': {'phone': '718-276-6101', 'website': 'http://www.eihab.org'},
#   'address': {'city': 'SPRINGFIELD GARDENS',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11434},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - RESOURCE CTR F/INDEPENDENT LIVING INC.',
#   'info': {'phone': '315-797-4642', 'website': 'http://www.rcil.com'},
#   'address': {'city': 'UTICA',
#    'county': 'ONEIDA',
#    'state': 'NY',
#    'zipcode': 13503},
#   'keywords': 'self,direction,services,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - EXCALIBUR LEISURE SKILLS CENTER INC.',
#   'info': {'phone': '716-831-3188', 'website': 'http://www.excaliburls.org'},
#   'address': {'city': 'BUFFALO',
#    'county': 'ERIE',
#    'state': 'NY',
#    'zipcode': 14216},
#   'keywords': 'family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - ANGELS UNAWARE INC.',
#   'info': {'phone': '718-410-7406', 'website': 'nan'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10452},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'BERNARD M. FINESON DDSO - SAMUEL FIELD YM-YWHA OF GREATER NYC',
#   'info': {'phone': '718-225-6750', 'website': 'http://www.sfy.org'},
#   'address': {'city': 'LITTLE NECK',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11362},
#   'keywords': 'family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - ACCESSCNY INC',
#   'info': {'phone': '315-455-7591', 'website': 'http://www.accesscny.org'},
#   'address': {'city': 'SYRACUSE',
#    'county': 'ONONDAGA',
#    'state': 'NY',
#    'zipcode': 13208},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': "LONG ISLAND DDSO - LIFE'S W.O.R.C. INC.",
#   'info': {'phone': '516-741-9000', 'website': 'http://www.lifesworc.org'},
#   'address': {'city': 'GARDEN CITY',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11530},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - LONG ISLAND HOME (THE)',
#   'info': {'phone': '631-608-5100',
#    'website': 'http://www.longislandhome.org'},
#   'address': {'city': 'AMITYVILLE',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11701},
#   'keywords': 'supported,employment,enrollments'},
#  {'facility': 'LONG ISLAND DDSO - MILL NECK SERVICES INC.',
#   'info': {'phone': '516-922-3818', 'website': 'nan'},
#   'address': {'city': 'MILL NECK',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11765},
#   'keywords': 'individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - SKILLS UNLIMITED INC.',
#   'info': {'phone': '631-567-3320',
#    'website': 'http://www.skillsunlimited.org'},
#   'address': {'city': 'OAKDALE',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11769},
#   'keywords': 'day,habilitation,supported,employment,enrollments'},
#  {'facility': 'WESTERN NEW YORK DDSO - ALLEGANY REGIONAL DEVELOPMENT CORP.',
#   'info': {'phone': '716-945-4100', 'website': 'nan'},
#   'address': {'city': 'SALAMANCA',
#    'county': 'CATTARAUGUS',
#    'state': 'NY',
#    'zipcode': 14779},
#   'keywords': 'community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - ACDS INC.',
#   'info': {'phone': '516-933-4700', 'website': 'http://www.acds.org'},
#   'address': {'city': 'PLAINVIEW',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11803},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'BROOME DDSO - ITHACA YOUTH BUREAU',
#   'info': {'phone': '607-273-8364', 'website': 'http://www.cityofithaca.org'},
#   'address': {'city': 'ITHACA',
#    'county': 'TOMPKINS',
#    'state': 'NY',
#    'zipcode': 14850},
#   'keywords': 'family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - PLUS GROUP HOMES',
#   'info': {'phone': '516-409-9450', 'website': 'http://plusgrouphomes.org'},
#   'address': {'city': 'WANTAGH',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11590},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,day,habilitation,community,habilitation'},
#  {'facility': 'CENTRAL NEW YORK DDSO - AURORA OF CNY INC.',
#   'info': {'phone': '315-422-7263', 'website': 'http://www.auroraofcny.org'},
#   'address': {'city': 'SYRACUSE',
#    'county': 'ONONDAGA',
#    'state': 'NY',
#    'zipcode': 13203},
#   'keywords': 'supported,employment,enrollments'},
#  {'facility': 'LONG ISLAND DDSO - A.C.L.D.',
#   'info': {'phone': '516-822-0028', 'website': 'http://www.acld.org'},
#   'address': {'city': 'BETHPAGE',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11714},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - EVELYN DOUGLIN CTR SERV. PEOPLE IN NEED',
#   'info': {'phone': '718-965-1998', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11232},
#   'keywords': 'individual,support,services,iss,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - OTSAR',
#   'info': {'phone': '718-946-7301', 'website': 'http://www.otsar.org'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11223},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - UNIV OF ROCHESTER/STRONG MEMORIAL HOSP.',
#   'info': {'phone': 'nan', 'website': 'http://www.rochester.edu'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14642},
#   'keywords': 'family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - CHAMPIONS FOR LIFE INC.',
#   'info': {'phone': '315-252-9305',
#    'website': 'http://www.championsforlife.org'},
#   'address': {'city': 'AUBURN',
#    'county': 'CAYUGA',
#    'state': 'NY',
#    'zipcode': 13021},
#   'keywords': 'family,support,services'},
#  {'facility': 'STATEN ISLAND DDSO - CITY ACCESS NEW YORK',
#   'info': {'phone': '718-285-6548', 'website': 'http://www.cityaccessny.org'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10310},
#   'keywords': 'day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - NICHOLAS CENTER',
#   'info': {'phone': '516-767-7177', 'website': 'nan'},
#   'address': {'city': 'PORT WASHINGTON',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11050},
#   'keywords': 'prevocational,supported,employment,enrollments,community,habilitation'},
#  {'facility': 'WESTERN NEW YORK DDSO - NYSARC INC CATTARAUGUS-NIAGARA CNTY CHAP',
#   'info': {'phone': '716-375-4747', 'website': 'http://www.rehabcenter.org'},
#   'address': {'city': 'OLEAN',
#    'county': 'CATTARAUGUS',
#    'state': 'NY',
#    'zipcode': 14760},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,family,care,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOME DDSO - FRANZISKA RACKER CENTERS INC.',
#   'info': {'phone': '607-272-5891', 'website': 'http://www.rackercenters.org'},
#   'address': {'city': 'ITHACA',
#    'county': 'TOMPKINS',
#    'state': 'NY',
#    'zipcode': 14850},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'TACONIC DDSO - TACONIC RESOURCES FOR INDEPENDENCE INC.',
#   'info': {'phone': '845-452-3913',
#    'website': 'http://www.taconicresources.org'},
#   'address': {'city': 'POUGHKEEPSIE',
#    'county': 'DUTCHESS',
#    'state': 'NY',
#    'zipcode': 12601},
#   'keywords': 'family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - DEVELOPMENTAL DISABILITIES INSTITUTE',
#   'info': {'phone': '631-366-2950', 'website': 'http://www.ddiny.org'},
#   'address': {'city': 'SMITHTOWN',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11787},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,self,direction,services,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOME DDSO - FAMILY ENRICHMENT NETWORK INC.',
#   'info': {'phone': '607-723-8313',
#    'website': 'http://www.familyenrichment.cc'},
#   'address': {'city': 'JOHNSON CITY',
#    'county': 'BROOME',
#    'state': 'NY',
#    'zipcode': 13790},
#   'keywords': 'prevocational,community,habilitation'},
#  {'facility': 'TACONIC DDSO - ABILITIES FIRST INC',
#   'info': {'phone': '845-485-9803',
#    'website': 'http://www.abilitiesfirstny.org'},
#   'address': {'city': 'POUGHKEEPSIE',
#    'county': 'DUTCHESS',
#    'state': 'NY',
#    'zipcode': 12603},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - SCHOOL OF HOLY CHILDHOOD',
#   'info': {'phone': '585-359-3710', 'website': 'http://www.holychildhood.org'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14623},
#   'keywords': 'day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'SUNMOUNT DDSO - ARC JEFFERSON-ST.LAWRENCE NEW YORK (THE)',
#   'info': {'phone': '315-788-2730', 'website': 'http://www.thejrc.org'},
#   'address': {'city': 'WATERTOWN',
#    'county': 'JEFFERSON',
#    'state': 'NY',
#    'zipcode': 13601},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - CAYUGA CENTERS',
#   'info': {'phone': '315-253-5383', 'website': 'http://www.cayugahome.org'},
#   'address': {'city': 'AUBURN',
#    'county': 'CAYUGA',
#    'state': 'NY',
#    'zipcode': 13021},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - LIBERTY RESOURCES INC.',
#   'info': {'phone': '315-425-1004',
#    'website': 'http://www.liberty-resources.org'},
#   'address': {'city': 'SYRACUSE',
#    'county': 'ONONDAGA',
#    'state': 'NY',
#    'zipcode': 13203},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - SALVATION ARMY (THE)',
#   'info': {'phone': '212-807-6100',
#    'website': 'http://www.use.salvationarmy.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10011},
#   'keywords': 'individual,residential,alternative,ira,family,care,community,habilitation'},
#  {'facility': 'CAPITAL DISTRICT DDSO - MONTGOMERY CO. NYSARC INC.',
#   'info': {'phone': '518-842-5080', 'website': 'http://www.libertyarc.org'},
#   'address': {'city': 'AMSTERDAM',
#    'county': 'MONTGOMERY',
#    'state': 'NY',
#    'zipcode': 12010},
#   'keywords': 'individual,residential,alternative,ira,family,care,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - CRYSTAL RUN VILLAGE INC.',
#   'info': {'phone': '845-692-4444',
#    'website': 'http://www.crvi.org/srvccoordination.asp'},
#   'address': {'city': 'MIDDLETOWN',
#    'county': 'ORANGE',
#    'state': 'NY',
#    'zipcode': 10940},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - HELEN KELLER SERVICES',
#   'info': {'phone': '516-485-1234', 'website': 'http://www.helenkeller.org'},
#   'address': {'city': 'HEMPSTEAD',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11550},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'CAPITAL DISTRICT DDSO - LIFESONG INC',
#   'info': {'phone': '518-406-5157', 'website': 'http://www.lifesonginc.org/'},
#   'address': {'city': 'CLIFTON PARK',
#    'county': 'SARATOGA',
#    'state': 'NY',
#    'zipcode': 12065},
#   'keywords': 'day,habilitation,supported,employment,enrollments,community,habilitation'},
#  {'facility': 'SUNMOUNT DDSO - ST REGIS MOHAWK TRIBE',
#   'info': {'phone': '518-358-9481',
#    'website': 'http://www.srmt-nsn.gov/contact'},
#   'address': {'city': 'AKWESASNE',
#    'county': 'FRANKLIN',
#    'state': 'NY',
#    'zipcode': 13655},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'CAPITAL DISTRICT DDSO - BATTENKILL COMMUNITY SERVICES INC.',
#   'info': {'phone': '518-692-2819', 'website': 'http://www.battenkill.org'},
#   'address': {'city': 'GREENWICH',
#    'county': 'WASHINGTON',
#    'state': 'NY',
#    'zipcode': 12834},
#   'keywords': 'individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - METROPOLITAN DEVELOPMENT CENTER',
#   'info': {'phone': '718-633-3334', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11219},
#   'keywords': 'self,direction,services,individual,support,services,iss,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - CARDINAL MCCLOSKEY SERVICES',
#   'info': {'phone': '914-997-8000',
#    'website': 'http://www.cardinalmccloskeyservices.org'},
#   'address': {'city': 'VALHALLA',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10595},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - JCC OF THE GREATER FIVE TOWNS',
#   'info': {'phone': '516-569-6733', 'website': 'http://www.fivetownsjcc.org'},
#   'address': {'city': 'CEDARHURST',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11516},
#   'keywords': 'family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - ADELANTE OF SUFFOLK COUNTY INC.',
#   'info': {'phone': '631-234-1049', 'website': 'http://www.adelantesc.org'},
#   'address': {'city': 'CENTRAL ISLIP',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11722},
#   'keywords': 'community,habilitation'},
#  {'facility': 'METRO NEW YORK DDSO - HARLEM DOWLING WESTSIDE CENTER',
#   'info': {'phone': '212-749-3656', 'website': 'http://www.harlemdowling.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10027},
#   'keywords': 'family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - THE SUMMIT CENTER INC.',
#   'info': {'phone': '716-629-3400', 'website': 'http://www.summited.org'},
#   'address': {'city': 'GETZVILLE',
#    'county': 'ERIE',
#    'state': 'NY',
#    'zipcode': 14068},
#   'keywords': 'day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - UCPA OF GREATER SUFFOLK INC',
#   'info': {'phone': '631-232-0011', 'website': 'http://www.ucp-suffolk.org'},
#   'address': {'city': 'HAUPPAUGE',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11788},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'TACONIC DDSO - DUTCHESS CO. NYSARC INC.',
#   'info': {'phone': '845-635-8084', 'website': 'http://dutchess-arc.org'},
#   'address': {'city': 'POUGHKEEPSIE',
#    'county': 'DUTCHESS',
#    'state': 'NY',
#    'zipcode': 12603},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - EPILEPSY ASSOCIATION OF WESTERN NY',
#   'info': {'phone': '716-883-5396', 'website': 'http://www.epilepsywny.com'},
#   'address': {'city': 'BUFFALO',
#    'county': 'ERIE',
#    'state': 'NY',
#    'zipcode': 14222},
#   'keywords': 'family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - SPECIAL CITIZENS FUTURES UNLIMITED INC.',
#   'info': {'phone': '212-643-2663',
#    'website': 'http://www.specialcitizens.org'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10453},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - MODERN GUIDANCE SERVICE',
#   'info': {'phone': '212-665-0091', 'website': 'nan'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10027},
#   'keywords': 'self,direction,services,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'STATEN ISLAND DDSO - PARENT TO PARENT OF N.Y. INC.',
#   'info': {'phone': '718-494-4872', 'website': 'http://parenttoparentnys.org'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10314},
#   'keywords': 'family,support,services'},
#  {'facility': 'BROOKLYN DDSO - HAMASPIK OF KINGS COUNTY INC.',
#   'info': {'phone': '718-387-8400', 'website': 'http://www.hamaspikkings.org'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11219},
#   'keywords': 'individual,residential,alternative,ira,family,care,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - INDEPENDENT SUPPORT SERVICES',
#   'info': {'phone': '845-794-5218', 'website': 'nan'},
#   'address': {'city': 'MONTICELLO',
#    'county': 'SULLIVAN',
#    'state': 'NY',
#    'zipcode': 12701},
#   'keywords': 'self,direction,services,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - TOWN OF NORTH HEMPSTEAD',
#   'info': {'phone': '516-327-3100',
#    'website': 'http://www.northhempstead.com'},
#   'address': {'city': 'NEW HYDE PARK',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11040},
#   'keywords': 'family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - CENTRO SOCIAL LA ESPERANZA INC.',
#   'info': {'phone': '212-928-5810',
#    'website': 'http://www.esperanzacenter.com/about-us.html'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10033},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - HOME PROGRAM INC. (THE)',
#   'info': {'phone': '914-332-4679',
#    'website': 'http://www.thehomeprogram.org'},
#   'address': {'city': 'WHITE PLAINS',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10602},
#   'keywords': 'family,support,services'},
#  {'facility': "METRO NEW YORK DDSO - CHILDREN'S AID SOCIETY",
#   'info': {'phone': '212-949-4800',
#    'website': 'http://www.childrensaidsociety.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10010},
#   'keywords': 'family,support,services'},
#  {'facility': 'BERNARD M. FINESON DDSO - WELLLIFE NETWORK INC.',
#   'info': {'phone': '718-445-4700', 'website': 'nan'},
#   'address': {'city': 'FLUSHING',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11351},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - NORTHEAST WESTCHESTER SPEC REC INC.',
#   'info': {'phone': '914-347-4409',
#    'website': 'http://www.northeastspecialrec.org'},
#   'address': {'city': 'HAWTHORNE',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10532},
#   'keywords': 'family,support,services'},
#  {'facility': 'BROOME DDSO - CATHOLIC CHARITIES OF CHENANGO COUNTY',
#   'info': {'phone': '607-334-8244', 'website': 'nan'},
#   'address': {'city': 'NORWICH',
#    'county': 'CHENANGO',
#    'state': 'NY',
#    'zipcode': 13815},
#   'keywords': 'individual,residential,alternative,ira,community,habilitation,family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - NYS ARC ALLEGANY COUNTY CHAPTER',
#   'info': {'phone': '585-593-5700', 'website': 'http://www.alleganyarc.org'},
#   'address': {'city': 'WELLSVILLE',
#    'county': 'ALLEGANY',
#    'state': 'NY',
#    'zipcode': 14895},
#   'keywords': 'individual,residential,alternative,ira,family,care,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - TOWN OF BROOKHAVEN',
#   'info': {'phone': '516-451-6100', 'website': 'http://www.brookhaven.org'},
#   'address': {'city': 'CORAM',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11727},
#   'keywords': 'family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - CP ROCHESTER (DBA)',
#   'info': {'phone': '585-334-6000', 'website': 'http://www.cprochester.org'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14623},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'BERNARD M. FINESON DDSO - QUEENS PARENT RESOURCE CENTER INC',
#   'info': {'phone': '347-947-6840', 'website': 'http://www.qprc.net'},
#   'address': {'city': 'QUEENS VILLAGE',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11429},
#   'keywords': 'individual,support,services,iss'},
#  {'facility': 'CENTRAL NEW YORK DDSO - LAUNCH',
#   'info': {'phone': '315-432-0665', 'website': 'http://www.launchcny.org'},
#   'address': {'city': 'SYRACUSE',
#    'county': 'ONONDAGA',
#    'state': 'NY',
#    'zipcode': 13203},
#   'keywords': 'individual,support,services,iss,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - BLOCK INSTITUTE',
#   'info': {'phone': '718-946-9700', 'website': 'http://blockinstitute.org'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11214},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - HEAD INJURY ASSOCIATION INC.',
#   'info': {'phone': '631-543-2245',
#    'website': 'http://www.headinjuryassoc.org'},
#   'address': {'city': 'HAUPPAUGE',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11788},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - LIFETIME ASSISTANCE INC.',
#   'info': {'phone': '585-426-4120',
#    'website': 'http://www.lifetimeassistance.org'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14624},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,family,care,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - STUDENT ADVOCACY',
#   'info': {'phone': '914-347-7039',
#    'website': 'http://www.studentadvocacy.net'},
#   'address': {'city': 'ELMSFORD',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10523},
#   'keywords': 'family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - COMMUNITY ASST. RESOURCES & EXTENDED SVC',
#   'info': {'phone': '212-420-1970', 'website': 'http://www.caresnyc.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10002},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - QUALITY SERVICES BEYOND COMPLIANCE',
#   'info': {'phone': '516-280-9361', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11221},
#   'keywords': 'individual,support,services,iss,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOME DDSO - CATHOLIC CHARITIES TOMPKINS & TIOGA CTY',
#   'info': {'phone': '607-272-5062', 'website': 'nan'},
#   'address': {'city': 'ITHACA',
#    'county': 'TOMPKINS',
#    'state': 'NY',
#    'zipcode': 14850},
#   'keywords': 'prevocational,community,habilitation'},
#  {'facility': 'HUDSON VALLEY DDSO - COMMUNITY BASED SERVICES INC.',
#   'info': {'phone': '914-277-4771',
#    'website': 'http://www.commbasedservices.org'},
#   'address': {'city': 'NORTH SALEM',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10560},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - ROCKLAND CO. NYSARC INC.',
#   'info': {'phone': '845-267-2500', 'website': 'http://www.arcofrockland.org'},
#   'address': {'city': 'CONGERS',
#    'county': 'ROCKLAND',
#    'state': 'NY',
#    'zipcode': 10920},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - CHILD & FAMILY SUPPORT SERVICES',
#   'info': {'phone': '718-618-7535', 'website': 'http://nycfss.org'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10451},
#   'keywords': 'day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - IBERO - AMERICAN ACTION LEAGUE',
#   'info': {'phone': '585-256-8900', 'website': 'http://www.iaal.org'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14605},
#   'keywords': 'individual,residential,alternative,ira,family,care,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - SERVICES FOR THE DEVELOP. CHALLENGED',
#   'info': {'phone': '718-432-8469', 'website': 'http://sdcnyc.org'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10471},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,prevocational,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - 0227 - LONG ISLAND DDSO',
#   'info': {'phone': '516-493-1700', 'website': 'nan'},
#   'address': {'city': 'COMMACK',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11725},
#   'keywords': 'individual,residential,alternative,ira,family,care,individual,support,services,iss,day,habilitation,family,support,services'},
#  {'facility': 'STATEN ISLAND DDSO - JEWISH COMMUNITY CENTER OF S.I.',
#   'info': {'phone': '718-981-1500', 'website': 'http://sijcc.org'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10314},
#   'keywords': 'day,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - URBAN LEAGUE OF ROCHESTER N.Y. INC.',
#   'info': {'phone': '585-325-6530', 'website': 'http://www.ulr.org'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14605},
#   'keywords': 'family,care,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - YATES CO. NYSARC INC.',
#   'info': {'phone': '315-536-7447', 'website': 'http://www.arcofyates.org'},
#   'address': {'city': 'PENN YAN',
#    'county': 'YATES',
#    'state': 'NY',
#    'zipcode': 14527},
#   'keywords': 'family,support,services'},
#  {'facility': 'TACONIC DDSO - MENTAL HEALTH ASSOC./ ULSTER COUNTY INC',
#   'info': {'phone': '845-336-4747', 'website': 'http://www.mhainulster.com'},
#   'address': {'city': 'KINGSTON',
#    'county': 'ULSTER',
#    'state': 'NY',
#    'zipcode': 12402},
#   'keywords': 'family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - CANTALICIAN CTR. FOR LEARNING INC.',
#   'info': {'phone': '716-901-8700', 'website': 'http://www.cantalician.org'},
#   'address': {'city': 'DEPEW',
#    'county': 'ERIE',
#    'state': 'NY',
#    'zipcode': 14043},
#   'keywords': 'day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOME DDSO - GROTON COMMUNITY HEALTH CARE CENTER',
#   'info': {'phone': '607-898-5876', 'website': 'http://www.gchcc.org'},
#   'address': {'city': 'GROTON',
#    'county': 'TOMPKINS',
#    'state': 'NY',
#    'zipcode': 13073},
#   'keywords': 'individual,residential,alternative,ira,community,habilitation'},
#  {'facility': "FINGER LAKES DDSO - MARY CARIOLA CHILDREN'S CENTER INC.",
#   'info': {'phone': '585-271-0761', 'website': 'http://www.marycariola.org'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14620},
#   'keywords': 'individual,residential,alternative,ira,community,habilitation,family,support,services'},
#  {'facility': 'STATEN ISLAND DDSO - LIFESTYLES FOR THE DISABLED',
#   'info': {'phone': '718-983-5351', 'website': 'http://www.lfdsi.org'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10314},
#   'keywords': 'self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - HERITAGE HUMAN SERVICES INC.',
#   'info': {'phone': '718-444-4340',
#    'website': 'http://www.heritagehumanservices.org'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11236},
#   'keywords': 'day,habilitation,prevocational,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - STEUBEN CO. NYSARC INC.',
#   'info': {'phone': '607-776-4146', 'website': 'http://arcofsteuben.org'},
#   'address': {'city': 'BATH',
#    'county': 'STEUBEN',
#    'state': 'NY',
#    'zipcode': 14810},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - 0261 - CENTRAL NEW YORK DDSO',
#   'info': {'phone': '315-473-2949', 'website': 'nan'},
#   'address': {'city': 'NORTH SYRACUSE',
#    'county': 'ONONDAGA',
#    'state': 'NY',
#    'zipcode': 13212},
#   'keywords': 'individual,residential,alternative,ira,family,care,day,habilitation,supported,employment,enrollments,community,habilitation'},
#  {'facility': 'HUDSON VALLEY DDSO - INCLUSIVE LINKS INC',
#   'info': {'phone': '914-294-0083', 'website': 'nan'},
#   'address': {'city': 'YONKERS',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10705},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - BIRCH FAMILY SERVICES',
#   'info': {'phone': '212-616-1800',
#    'website': 'http://www.birchfamilyservices.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10001},
#   'keywords': 'intermediate,care,facilities,icf,prevocational,supported,employment,enrollments,community,habilitation'},
#  {'facility': 'BROOME DDSO - PATHFINDER VILLAGE INC.',
#   'info': {'phone': '607-965-8377',
#    'website': 'http://www.pathfindervillage.org'},
#   'address': {'city': 'EDMESTON',
#    'county': 'OTSEGO',
#    'state': 'NY',
#    'zipcode': 13335},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,prevocational,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - CHILD CARE COUNCIL INC',
#   'info': {'phone': 'nan', 'website': 'nan'},
#   'address': {'city': 'ROCHESTER',
#    'county': 'MONROE',
#    'state': 'NY',
#    'zipcode': 14610},
#   'keywords': 'family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - VIABILITY INC.',
#   'info': {'phone': '631-952-9529',
#    'website': 'http://www.communityenterprises.com/locations/islandia'},
#   'address': {'city': 'ISLANDIA',
# ...
#   'address': {'city': 'VALHALLA',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10595},
#   'keywords': 'day,habilitation,prevocational,supported,employment,enrollments'},
#  {'facility': 'SUNMOUNT DDSO - FRANKLIN-ESSEX-HAMILTON BOCES',
#   'info': {'phone': '518-483-5230', 'website': 'nan'},
#   'address': {'city': 'MALONE',
#    'county': 'FRANKLIN',
#    'state': 'NY',
#    'zipcode': 12953},
#   'keywords': 'supported,employment,enrollments'},
#  {'facility': 'METRO NEW YORK DDSO - SOCIAL ACTION CENTER INC.',
#   'info': {'phone': '718-654-1815', 'website': 'nan'},
#   'address': {'city': 'BRONX',
#    'county': 'BRONX',
#    'state': 'NY',
#    'zipcode': 10467},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - THE RESOURCE CENTER',
#   'info': {'phone': '716-483-2344', 'website': 'http://resourcecenter.org/'},
#   'address': {'city': 'JAMESTOWN',
#    'county': 'CHAUTAUQUA',
#    'state': 'NY',
#    'zipcode': 14701},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,family,care,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - REHABILITATION INSTITUTE (THE)',
#   'info': {'phone': '516-222-2092', 'website': 'https://www.aquent.com/'},
#   'address': {'city': 'WESTBURY',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11950},
#   'keywords': 'day,habilitation'},
#  {'facility': 'HUDSON VALLEY DDSO - YWCA WHITE PLAINS & CENTRAL WESTCHESTER',
#   'info': {'phone': '914-949-6227', 'website': 'http://ywcawhiteplains.com'},
#   'address': {'city': 'WHITE PLAINS',
#    'county': 'WESTCHESTER',
#    'state': 'NY',
#    'zipcode': 10605},
#   'keywords': 'family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - CAYUGA COUNSELING SERVICES',
#   'info': {'phone': '315-253-9795', 'website': 'nan'},
#   'address': {'city': 'AUBURN',
#    'county': 'CAYUGA',
#    'state': 'NY',
#    'zipcode': 13021},
#   'keywords': 'family,support,services'},
#  {'facility': 'CAPITAL DISTRICT DDSO - LIBERTY HOUSE',
#   'info': {'phone': '518-798-1066',
#    'website': 'http://www.libertyhousefoundation.net'},
#   'address': {'city': 'GLENS FALLS',
#    'county': 'WARREN',
#    'state': 'NY',
#    'zipcode': 12801},
#   'keywords': 'prevocational,supported,employment,enrollments'},
#  {'facility': 'CENTRAL NEW YORK DDSO - SALVATION ARMY - SYRACUSE AREA SVCS',
#   'info': {'phone': '315-475-1688',
#    'website': 'http://www.use.salvationarmy.org'},
#   'address': {'city': 'SYRACUSE',
#    'county': 'ONONDAGA',
#    'state': 'NY',
#    'zipcode': 13202},
#   'keywords': 'day,habilitation'},
#  {'facility': 'METRO NEW YORK DDSO - QSAC INC.',
#   'info': {'phone': '212-244-5560', 'website': 'http://www.qsac.com'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10001},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - THE ARC (ONEIDA-LEWIS NYSARC CHAPTERS)',
#   'info': {'phone': '315-735-6477', 'website': 'http://www.thearcolc.org'},
#   'address': {'city': 'UTICA',
#    'county': 'ONEIDA',
#    'state': 'NY',
#    'zipcode': 13501},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - MY TIME INC.',
#   'info': {'phone': '718-251-0527', 'website': 'http://mytimeinc.org/'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11236},
#   'keywords': 'family,support,services'},
#  {'facility': 'BERNARD M. FINESON DDSO - SERENITY HUMAN SERVICES INC.',
#   'info': {'phone': '718-526-6125', 'website': 'http://tendercareny.org'},
#   'address': {'city': 'ROSEDALE',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11422},
#   'keywords': 'individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - YEDEI CHESED INC.',
#   'info': {'phone': '845-425-0887', 'website': 'http://www.yedeichesed.org'},
#   'address': {'city': 'CHESTNUT RIDGE',
#    'county': 'ROCKLAND',
#    'state': 'NY',
#    'zipcode': 10977},
#   'keywords': 'individual,residential,alternative,ira,family,care,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'TACONIC DDSO - TACONIC INNOVATIONS INC.',
#   'info': {'phone': '845-296-1042',
#    'website': 'http://www.taconicinnovations.com'},
#   'address': {'city': 'WAPPINGERS FALLS',
#    'county': 'DUTCHESS',
#    'state': 'NY',
#    'zipcode': 12590},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - COMMUNITY ACTION PROGRAM FOR MADISON CO.',
#   'info': {'phone': '315-684-3144', 'website': 'http://www.capmadco.org'},
#   'address': {'city': 'MORRISVILLE',
#    'county': 'MADISON',
#    'state': 'NY',
#    'zipcode': 13408},
#   'keywords': 'family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - ARC OF GENESEE ORLEANS',
#   'info': {'phone': '585-343-1123', 'website': 'http://www.arcoforleans.org'},
#   'address': {'city': 'BATAVIA',
#    'county': 'GENESEE',
#    'state': 'NY',
#    'zipcode': 14020},
#   'keywords': 'individual,residential,alternative,ira,family,care,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - A.R.C. INC.',
#   'info': {'phone': '718-531-7500', 'website': 'http://www.arcny.org'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11234},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,day,habilitation,prevocational,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - DUNBAR ASSOCIATION INC.',
#   'info': {'phone': '315-476-4269',
#    'website': 'http://www.dunbarassociation.org'},
#   'address': {'city': 'SYRACUSE',
#    'county': 'ONONDAGA',
#    'state': 'NY',
#    'zipcode': 13205},
#   'keywords': 'family,support,services'},
#  {'facility': 'BERNARD M. FINESON DDSO - GENERAL HUMAN OUTREACH IN THE COMMUNITY',
#   'info': {'phone': '718-261-6552', 'website': 'http://www.ghoinc.org'},
#   'address': {'city': 'KEW GARDENS',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11415},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': "LONG ISLAND DDSO - BROOKVILLE CNTR FOR CHILDREN'S SERVS INC",
#   'info': {'phone': 'nan', 'website': 'http://www.ahrc.org'},
#   'address': {'city': 'BROOKVILLE',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11545},
#   'keywords': 'intermediate,care,facilities,icf,family,support,services'},
#  {'facility': 'SUNMOUNT DDSO - BOCES - ST. LAWRENCE - LEWIS',
#   'info': {'phone': '315-386-4504', 'website': 'http://www.sllboces.org'},
#   'address': {'city': 'CANTON',
#    'county': 'ST. LAWRENCE',
#    'state': 'NY',
#    'zipcode': 13617},
#   'keywords': 'supported,employment,enrollments'},
#  {'facility': 'LONG ISLAND DDSO - EPIC LONG ISLAND INC.',
#   'info': {'phone': '516-739-7733', 'website': 'http://www.efli.org'},
#   'address': {'city': 'EAST MEADOW',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11554},
#   'keywords': 'individual,residential,alternative,ira,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - KULANU ACADEMY',
#   'info': {'phone': '516-569-6664', 'website': 'http://www.kulanukids.org'},
#   'address': {'city': 'CEDARHURST',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11516},
#   'keywords': 'day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - SPECIAL CARE FOR FAMILIES & CHILDREN SVC',
#   'info': {'phone': '718-252-3365', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11230},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'BERNARD M. FINESON DDSO - UNITING DISABLED INDIVIDUALS',
#   'info': {'phone': '718-297-3344', 'website': 'nan'},
#   'address': {'city': 'JAMAICA',
#    'county': 'QUEENS',
#    'state': 'NY',
#    'zipcode': 11435},
#   'keywords': 'family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - OSWEGO COUNTY OPPORTUNITIES INC.',
#   'info': {'phone': '315-598-4710', 'website': 'http://www.oco.org/'},
#   'address': {'city': 'FULTON',
#    'county': 'OSWEGO',
#    'state': 'NY',
#    'zipcode': 13069},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'METRO NEW YORK DDSO - CATHOLIC GUARDIAN SERVICES',
#   'info': {'phone': '212-371-1000',
#    'website': 'http://www.catholicguardian.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10022},
#   'keywords': 'individual,residential,alternative,ira,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'WESTERN NEW YORK DDSO - CHAUTAUQUA ADULT DAY CARE CENTERS INC.',
#   'info': {'phone': '716-665-4822',
#    'website': 'http://www.seniordayprograms.com'},
#   'address': {'city': 'JAMESTOWN',
#    'county': 'CHAUTAUQUA',
#    'state': 'NY',
#    'zipcode': 14701},
#   'keywords': 'day,habilitation'},
#  {'facility': 'METRO NEW YORK DDSO - INSTITUTE FOR COMMUNITY LIVING',
#   'info': {'phone': '212-385-3030', 'website': 'http://www.iclinc.net'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10004},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,community,habilitation'},
#  {'facility': 'BROOKLYN DDSO - HEBREW EDUCATIONAL SOCIETY',
#   'info': {'phone': '718-241-3000', 'website': 'http://www.thehes.org'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11236},
#   'keywords': 'family,support,services'},
#  {'facility': 'STATEN ISLAND DDSO - MODEST COMMUNITY SERVICES ASSOCIATION',
#   'info': {'phone': '718-447-8200', 'website': 'http://modestservices.org'},
#   'address': {'city': 'STATEN ISLAND',
#    'county': 'RICHMOND',
#    'state': 'NY',
#    'zipcode': 10306},
#   'keywords': 'individual,residential,alternative,ira,individual,support,services,iss,day,habilitation,community,habilitation'},
#  {'facility': 'LONG ISLAND DDSO - TOWN OF OYSTER BAY RECREATION',
#   'info': {'phone': '516-797-7900', 'website': 'nan'},
#   'address': {'city': 'MASSAPEQUA',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11758},
#   'keywords': 'family,support,services'},
#  {'facility': 'CAPITAL DISTRICT DDSO - NEW BEGINNINGS MSC INC.',
#   'info': {'phone': '518-326-3322', 'website': 'nan'},
#   'address': {'city': 'TROY',
#    'county': 'RENSSELAER',
#    'state': 'NY',
#    'zipcode': 12180},
#   'keywords': 'community,habilitation,family,support,services'},
#  {'facility': "BROOME DDSO - CHILDREN'S HOME OF WYOMING CONFERENCE",
#   'info': {'phone': '607-772-6904', 'website': 'nan'},
#   'address': {'city': 'BINGHAMTON',
#    'county': 'BROOME',
#    'state': 'NY',
#    'zipcode': 13901},
#   'keywords': 'family,support,services'},
#  {'facility': 'HUDSON VALLEY DDSO - THE CENTER FOR DISCOVERY INC',
#   'info': {'phone': '845-794-1400', 'website': 'http://www.sdtc.org'},
#   'address': {'city': 'HARRIS',
#    'county': 'SULLIVAN',
#    'state': 'NY',
#    'zipcode': 12742},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,day,habilitation,community,habilitation'},
#  {'facility': 'METRO NEW YORK DDSO - NYS ARC NEW YORK CITY CHAPTER',
#   'info': {'phone': '212-780-2500', 'website': 'http://www.ahrcnyc.org'},
#   'address': {'city': 'NEW YORK',
#    'county': 'NEW YORK',
#    'state': 'NY',
#    'zipcode': 10038},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'BROOME DDSO - CATHOLIC CHARITIES OF BROOME INC',
#   'info': {'phone': '607-729-9166',
#    'website': 'http://catholiccharitiesbc.org'},
#   'address': {'city': 'BINGHAMTON',
#    'county': 'BROOME',
#    'state': 'NY',
#    'zipcode': 13905},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,community,habilitation'},
#  {'facility': 'BROOKLYN DDSO - MEANINGFUL NY INITIATVES PPL W/DISAB INC',
#   'info': {'phone': '929-409-1027', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11201},
#   'keywords': 'self,direction,services,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - HAPPINESS HOUSE',
#   'info': {'phone': '315-789-6828',
#    'website': 'http://www.happinesshouse.org'},
#   'address': {'city': 'GENEVA',
#    'county': 'ONTARIO',
#    'state': 'NY',
#    'zipcode': 14456},
#   'keywords': 'individual,residential,alternative,ira,self,direction,services,individual,support,services,iss,day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - UCP BAYVILLE INCORPORATED',
#   'info': {'phone': '516-378-2000', 'website': 'http://www.ucpn.org'},
#   'address': {'city': 'ROOSEVELT',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11575},
#   'keywords': 'intermediate,care,facilities,icf'},
#  {'facility': 'BROOKLYN DDSO - HEART AND SOUL SERVICES INC.',
#   'info': {'phone': '718-612-1080', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11218},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'BROOKLYN DDSO - UNIQUE CARE COMMUNITY SERVICES INC.',
#   'info': {'phone': '347-502-2956', 'website': 'nan'},
#   'address': {'city': 'BROOKLYN',
#    'county': 'KINGS',
#    'state': 'NY',
#    'zipcode': 11236},
#   'keywords': 'day,habilitation,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - SUFFOLK CO. NYSARC INC.',
#   'info': {'phone': '631-585-0100', 'website': 'http://www.ahrcsuffolk.org'},
#   'address': {'city': 'BOHEMIA',
#    'county': 'SUFFOLK',
#    'state': 'NY',
#    'zipcode': 11716},
#   'keywords': 'intermediate,care,facilities,icf,individual,residential,alternative,ira,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'FINGER LAKES DDSO - ONTARIO CO. NYSARC INC.',
#   'info': {'phone': '585-394-7500', 'website': 'http://www.ontarioarc.org'},
#   'address': {'city': 'CANANDAIGUA',
#    'county': 'ONTARIO',
#    'state': 'NY',
#    'zipcode': 14424},
#   'keywords': 'individual,residential,alternative,ira,family,care,day,habilitation,prevocational,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'CENTRAL NEW YORK DDSO - HERITAGE FARM INC.',
#   'info': {'phone': '315-893-1889', 'website': 'http://heritagefarminc.org'},
#   'address': {'city': 'BOUCKVILLE',
#    'county': 'MADISON',
#    'state': 'NY',
#    'zipcode': 13310},
#   'keywords': 'day,habilitation,supported,employment,enrollments,community,habilitation,family,support,services'},
#  {'facility': 'LONG ISLAND DDSO - CENTER FOR FAMILY SUPPORT INC. (THE)',
#   'info': {'phone': '516-292-3000', 'website': 'http://www.cfsny.org'},
#   'address': {'city': 'FLORAL PARK',
#    'county': 'NASSAU',
#    'state': 'NY',
#    'zipcode': 11001},
#   'keywords': 'individual,support,services,iss,community,habilitation,family,support,services'}]

# %%
# Use specific database and show details.
Database.use("providers")
# Out:
# OK
# Database(MongoClient(host=['mongodb.thelionsredmane.stream:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin'), 'providers')

# %%
# Insert many.
# Database.insert_many("services", payload)
